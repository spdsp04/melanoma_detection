# %% [markdown]
# # Problem Statement (Melanoma Detection)

# %% [markdown]
# >To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution that can evaluate images and alert dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.
#
# >The dataset consists of 2357 images of malignant and benign oncological diseases, which were formed from the International Skin Imaging Collaboration (ISIC). All images were sorted according to the classification taken with ISIC, and all subsets were divided into the same number of images, with the exception of melanomas and moles, whose images are slightly dominant.
#
# >The data set contains the following diseases:
#
# >- Actinic keratosis
# >- Basal cell carcinoma
# >- Dermatofibroma
# >- Melanoma
# >- Nevus
# >- Pigmented benign keratosis
# >- Seborrheic keratosis
# >- Squamous cell carcinoma
# >- Vascular lesion

# %% [markdown]
# **Tensorflow, keras and Augmentor to be in installed first if not available in Environment by using below mentioned commands.**
#
# !pip install tensorflow
#
# !pip install keras
#
# !pip install Augmentor

# %% [markdown]
# ### Importing Dataset

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization, Rescaling, InputLayer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Checking versions of Libraries
f'NumPy version: {np.__version__} | Pandas version: {pd.__version__} | keras version: {keras.__version__}'
# Out:
# 'NumPy version: 1.21.6 | Pandas version: 1.3.5 | keras version: 2.8.0'

# %%
# Importing from local machine
data_dir_train = pathlib.Path("/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
# to count total no of images in dataset
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# **Load using keras.preprocessing**
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.
#
# **Defining dataset**
#
# Define some batch size, height and width of image to load

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# **Image loading by using keras.preprocessing**
#
# Image to be loaded off from dataset by image_dataset_from_directory utility.
#
# Splitting 80% of the data for training the model and 20% for validation segment.

# %%
# segmenting train and validation set from dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  label_mode="int",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
# Segregation of validation set from dataset
validation_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  label_mode="int",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# Classifying all type of skin cancer
Name_of_class = train_dataset.class_names
print(Name_of_class)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
# Coutning no's of images in each class type of Train datset
for i in Name_of_class:
  print(i,": ",len(list(data_dir_train.glob('{}/*.jpg'.format(i)))))
# Out:
# actinic keratosis :  114
# basal cell carcinoma :  376
# dermatofibroma :  95
# melanoma :  438
# nevus :  357
# pigmented benign keratosis :  462
# seborrheic keratosis :  77
# squamous cell carcinoma :  181
# vascular lesion :  139

# %%
# Coutning no's of images in each class type of Test datset
for i in Name_of_class:
  print(i,": ",len(list(data_dir_test.glob('{}/*.jpg'.format(i)))))
# Out:
# actinic keratosis :  16
# basal cell carcinoma :  16
# dermatofibroma :  16
# melanoma :  16
# nevus :  16
# pigmented benign keratosis :  16
# seborrheic keratosis :  3
# squamous cell carcinoma :  16
# vascular lesion :  3

# %% [markdown]
# ### Data Visulisation

# %% [markdown]
# Having random view of each type of Images

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for index,images in enumerate(Name_of_class):
  
  temp=plt.imread(list(data_dir_train.glob('{}/*.jpg'.format(images)))[0])
  
  plt.subplot(3,3,index+1)
  plt.imshow(temp)
  plt.axis('off')
  plt.title(images)

# %%
# to confirm shape and size of Image
for image_batch, labels_batch in train_dataset:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# A tensor of the size (32, 180, 180, 3) is dimension of one image batch. Here it is group of 32 images with dimension 180x180x3 (the last one is for color channels RGB).

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_dataset= validation_dataset.cache().prefetch(buffer_size=AUTOTUNE)

#Dataset.cache() keeps the images in memory after they're loaded off disk during the first epoch.

#Dataset.prefetch() overlaps data preprocessing and model execution while training.

# %% [markdown]
# **Standardization of images**
#
# The RGB channel values ranges in between 0 to 225, which is not good in case of neural network. Ideally it should be in between 0 and 1.

# %%
normalised_layer = tf.keras.layers.Rescaling(1./255)
normalized_dataset = train_dataset.map(lambda x, y: (normalised_layer(x), y))
image_batch, labels_batch = next(iter(normalized_dataset))

# %% [markdown]
# ### Model 1

# %% [markdown]
# Creating First model to identify total 9 classes in dataset.

# %%
model=Sequential([layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))])

model.add(Conv2D(16, 3, activation='relu',padding='same', input_shape = (180, 180, 32)))
model.add(MaxPooling2D())

model.add(Conv2D(32, 3, activation='relu',padding='same'))
model.add(MaxPooling2D())
model.add(Conv2D(64, 3, activation='relu',padding='same'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(9, activation='softmax'))

# %% [markdown]
# **Compilation of Model**
#
# Using adam as optimiser and loss function to train the Model

# %%
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# Checking summery of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the Model after optimising with 20 epochs

# %%
epochs = 20
history = model.fit(
  train_dataset,
  validation_data=validation_dataset,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 61s 899ms/step - loss: 1.8862 - accuracy: 0.2941 - val_loss: 1.6340 - val_accuracy: 0.4004
# Epoch 2/20
# 56/56 [==============================] - 3s 47ms/step - loss: 1.5861 - accuracy: 0.4559 - val_loss: 1.4684 - val_accuracy: 0.5123
# Epoch 3/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.4270 - accuracy: 0.5017 - val_loss: 1.4008 - val_accuracy: 0.5280
# Epoch 4/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.2969 - accuracy: 0.5363 - val_loss: 1.4141 - val_accuracy: 0.5347
# Epoch 5/20
# 56/56 [==============================] - 3s 48ms/step - loss: 1.2084 - accuracy: 0.5759 - val_loss: 1.3008 - val_accuracy: 0.5548
# Epoch 6/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.1349 - accuracy: 0.5971 - val_loss: 1.3714 - val_accuracy: 0.5436
# Epoch 7/20
# 56/56 [==============================] - 3s 45ms/step - loss: 1.0008 - accuracy: 0.6456 - val_loss: 1.4813 - val_accuracy: 0.5391
# Epoch 8/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.9439 - accuracy: 0.6641 - val_loss: 1.4328 - val_accuracy: 0.5280
# Epoch 9/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.8198 - accuracy: 0.6903 - val_loss: 1.6717 - val_accuracy: 0.4989
# Epoch 10/20
# 56/56 [==============================] - 3s 48ms/step - loss: 0.7289 - accuracy: 0.7388 - val_loss: 1.7208 - val_accuracy: 0.5101
# Epoch 11/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.6077 - accuracy: 0.7734 - val_loss: 1.6551 - val_accuracy: 0.5257
# Epoch 12/20
# 56/56 [==============================] - 3s 46ms/step - loss: 0.5240 - accuracy: 0.8092 - val_loss: 2.1088 - val_accuracy: 0.5302
# Epoch 13/20
# 56/56 [==============================] - 3s 46ms/step - loss: 0.4466 - accuracy: 0.8337 - val_loss: 2.0237 - val_accuracy: 0.5414
# Epoch 14/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.3698 - accuracy: 0.8633 - val_loss: 2.1165 - val_accuracy: 0.5257
# Epoch 15/20
# 56/56 [==============================] - 3s 46ms/step - loss: 0.3111 - accuracy: 0.8823 - val_loss: 2.0784 - val_accuracy: 0.5324
# Epoch 16/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.3498 - accuracy: 0.8733 - val_loss: 2.5353 - val_accuracy: 0.5481
# Epoch 17/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.2637 - accuracy: 0.8890 - val_loss: 2.3906 - val_accuracy: 0.5548
# Epoch 18/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.2251 - accuracy: 0.9085 - val_loss: 2.3647 - val_accuracy: 0.5481
# Epoch 19/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.1968 - accuracy: 0.9224 - val_loss: 2.4615 - val_accuracy: 0.5638
# Epoch 20/20
# 56/56 [==============================] - 3s 45ms/step - loss: 0.1801 - accuracy: 0.9224 - val_loss: 2.6361 - val_accuracy: 0.5391

# %% [markdown]
# ### Checking results of Model 1

# %%
accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Findings:**
#
# Train Data Accuracy : 0.9224
#
# Train Loss : 0.1801
#
# Validation Data Accuracy : 0.5391
#
# Validation Loss - 2.6361
#
# **Nutshell:**
#
# Accuracy figures indicates that model is highly overfit, secondly loss value of validation dataset is higher.
#
# **Correction:**
# Model need augmentation also dropout in layers.

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# Augmentation is kind of apply flip, rotate, zoom for data input while model building, to enhance result.

# %%
data_augmentation = keras.Sequential([layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_augmentation1=ImageDataGenerator(rescale=1./255,
                   horizontal_flip=True,
                   zoom_range=0.2)
image_batch,label_batch=next(iter(train_dataset))
temp=image_batch[0].numpy()
plt.imshow(temp.astype('uint8'))

# %%
#Checking effect of augmentation on one of image
plt.imshow(data_augmentation1.apply_transform(temp,transform_parameters={'flip_horizontal':True}).astype('uint8'))

# %% [markdown]
# ### Building Model 2 after Augmentation

# %%
Augmented_data_model=Sequential([data_augmentation,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
Augmented_data_model.add(Conv2D(16, 3, activation='relu',padding='same',input_shape = (180, 180, 32)))
Augmented_data_model.add(MaxPooling2D())

Augmented_data_model.add(Conv2D(32, 3, activation='relu',padding='same'))
Augmented_data_model.add(MaxPooling2D())
Augmented_data_model.add(Conv2D(64, 3, activation='relu',padding='same'))
Augmented_data_model.add(MaxPooling2D())
Augmented_data_model.add(Dropout(0.25))

Augmented_data_model.add(Flatten())
Augmented_data_model.add(Dense(128, activation='relu'))
Augmented_data_model.add(Dense(9, activation='softmax'))

# %%
#Compiling the model built after data augmentation
Augmented_data_model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# Checking summary of Model built by augmenting data
Augmented_data_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training model after data augmentation with 20 epoches
epochs = 20
history = Augmented_data_model.fit(
  train_dataset,
  validation_data=validation_dataset,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 5s 57ms/step - loss: 2.0725 - accuracy: 0.1842 - val_loss: 1.9586 - val_accuracy: 0.2752
# Epoch 2/20
# 56/56 [==============================] - 3s 55ms/step - loss: 1.8955 - accuracy: 0.2930 - val_loss: 2.0006 - val_accuracy: 0.2371
# Epoch 3/20
# 56/56 [==============================] - 3s 54ms/step - loss: 1.6697 - accuracy: 0.3895 - val_loss: 1.4923 - val_accuracy: 0.4922
# Epoch 4/20
# 56/56 [==============================] - 3s 54ms/step - loss: 1.5177 - accuracy: 0.4615 - val_loss: 1.6262 - val_accuracy: 0.4676
# Epoch 5/20
# 56/56 [==============================] - 3s 55ms/step - loss: 1.4364 - accuracy: 0.4994 - val_loss: 1.5836 - val_accuracy: 0.4609
# Epoch 6/20
# 56/56 [==============================] - 3s 55ms/step - loss: 1.4312 - accuracy: 0.4978 - val_loss: 1.5122 - val_accuracy: 0.4832
# Epoch 7/20
# 56/56 [==============================] - 3s 55ms/step - loss: 1.3420 - accuracy: 0.5374 - val_loss: 1.4405 - val_accuracy: 0.5235
# Epoch 8/20
# 56/56 [==============================] - 3s 55ms/step - loss: 1.2891 - accuracy: 0.5352 - val_loss: 1.3413 - val_accuracy: 0.5302
# Epoch 9/20
# 56/56 [==============================] - 3s 56ms/step - loss: 1.2770 - accuracy: 0.5541 - val_loss: 1.3538 - val_accuracy: 0.5391
# Epoch 10/20
# 56/56 [==============================] - 3s 56ms/step - loss: 1.2206 - accuracy: 0.5552 - val_loss: 1.4080 - val_accuracy: 0.5324
# Epoch 11/20
# 56/56 [==============================] - 3s 56ms/step - loss: 1.2429 - accuracy: 0.5485 - val_loss: 1.6111 - val_accuracy: 0.4832
# Epoch 12/20
# 56/56 [==============================] - 3s 55ms/step - loss: 1.2309 - accuracy: 0.5608 - val_loss: 1.3608 - val_accuracy: 0.5391
# Epoch 13/20
# 56/56 [==============================] - 3s 54ms/step - loss: 1.2278 - accuracy: 0.5619 - val_loss: 1.3581 - val_accuracy: 0.5391
# Epoch 14/20
# 56/56 [==============================] - 3s 55ms/step - loss: 1.1560 - accuracy: 0.5826 - val_loss: 1.3105 - val_accuracy: 0.5324
# Epoch 15/20
# 56/56 [==============================] - 3s 59ms/step - loss: 1.1873 - accuracy: 0.5725 - val_loss: 1.3844 - val_accuracy: 0.5257
# Epoch 16/20
# 56/56 [==============================] - 3s 62ms/step - loss: 1.1624 - accuracy: 0.5792 - val_loss: 1.4042 - val_accuracy: 0.5235
# Epoch 17/20
# 56/56 [==============================] - 3s 54ms/step - loss: 1.1806 - accuracy: 0.5714 - val_loss: 1.4057 - val_accuracy: 0.5213
# Epoch 18/20
# 56/56 [==============================] - 3s 54ms/step - loss: 1.1729 - accuracy: 0.5765 - val_loss: 1.2960 - val_accuracy: 0.5593
# Epoch 19/20
# 56/56 [==============================] - 3s 54ms/step - loss: 1.1358 - accuracy: 0.5898 - val_loss: 1.2645 - val_accuracy: 0.5459
# Epoch 20/20
# 56/56 [==============================] - 3s 54ms/step - loss: 1.1124 - accuracy: 0.5965 - val_loss: 1.3549 - val_accuracy: 0.5369

# %%
# Visualizing the result
accuracy = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, accuracy, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Findings:**
#
# Train Data Accuracy : 0.5965
#
# Train Loss : 1.1124
#
# Validation Data Accuracy : 0.5369
#
# Validation Loss - 1.3549
#
# **Nutshell:**
#
# Accuracy figures indicates that model is highly underfit.
#
# **Correction:**
# Data imbalancing to be checked.

# %% [markdown]
# ### Class Imbalance checking

# %% [markdown]
# Numerous datasets can have class awkwardness, one class can have proportionately larger number of tests contrasted with the others. Class irregularity can unfavorably affect the last model quality. Consequently as a second look just in case it becomes essential to actually look at what is the dispersion of classes in the information.

# %%
for i in Name_of_class:
  print(i,": ",len(list(data_dir_train.glob('{}/*.jpg'.format(i)))))
# Out:
# actinic keratosis :  114
# basal cell carcinoma :  376
# dermatofibroma :  95
# melanoma :  438
# nevus :  357
# pigmented benign keratosis :  462
# seborrheic keratosis :  77
# squamous cell carcinoma :  181
# vascular lesion :  139

# %%
# Visualize class imbalance through chart
count=[]
for i in Name_of_class:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(Name_of_class,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# **'seborrheic keratosis'** is having the least no of images i,e 77
#
# **'pigmented benign keratosis'** is having the maximum no of images i,e 462

# %%
# lebel checking
path_list=[]
lesion_list=[]
for i in Name_of_class:
      for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 1     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 2     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 3     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# 4     /content/drive/MyDrive/Skin cancer ISIC The In...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2235  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2236  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2237  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
# 2238  /content/drive/MyDrive/Skin cancer ISIC The In...    vascular lesion
#
# [2239 rows x 2 columns]

# %% [markdown]
# **Augmentor Package**
#
# A python package known as Augmentor is utilized to add more examples across all classes with the goal that none of the classes have not many examples.

# %% [markdown]
# Procedure to use Agumentor:
#
# 1. Start pipeline to folder of sample image
# 2. Mention nos of operation to be done on pipline object.
# 3. Call the method

# %%
import Augmentor
for i in Name_of_class:
  augmnt_pipeline = Augmentor.Pipeline(str(data_dir_train) + '/'+ i)
  augmnt_pipeline.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
  augmnt_pipeline.sample(500)
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F8FFCCBDC90>: 100%|██████████| 500/500 [00:21<00:00, 23.66 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F8FFCF74610>: 100%|██████████| 500/500 [00:21<00:00, 23.17 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F9076EA2650>: 100%|██████████| 500/500 [00:22<00:00, 22.72 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8FFCC44610>: 100%|██████████| 500/500 [01:44<00:00,  4.80 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=576x768 at 0x7F8FFCD2D9D0>: 100%|██████████| 500/500 [01:37<00:00,  5.12 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F9078B0C3D0>: 100%|██████████| 500/500 [00:23<00:00, 21.08 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F8FFCF545D0>: 100%|██████████| 500/500 [00:49<00:00, 10.05 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F8FFCC826D0>: 100%|██████████| 500/500 [00:22<00:00, 22.43 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/drive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F8FFD4CD790>: 100%|██████████| 500/500 [00:24<00:00, 20.81 Samples/s]

# %% [markdown]
# Augmentor has stored agumented images in the new subfolder output folder of each class folder. Lets have count for total.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# **Checking distribution of augmented data after adding new images to the original training data.**

# %%
import os
import glob
from glob import glob
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: Label, dtype: int64

# %% [markdown]
# Now we have added 500 images to all the classes to maintain some class balance.

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# **Splitting Training dataset**

# %%
augmented_data_dir = data_dir_train
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  augmented_data_dir,
  seed=123,
  validation_split = 0.2,
  subset ='training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# **segmenting train and validation set from dataset**

# %%
validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
  augmented_data_dir,
  seed=123,
  validation_split = 0.2,
  subset ='validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# ### Building Model 3 After additional 500 images in output folder

# %%
# Include BatchNormalization, Dropout
Normalised_Model=Sequential()

Normalised_Model.add(InputLayer((180,180,3)))
Normalised_Model.add(Rescaling(1./255))

Normalised_Model.add(Conv2D(32, (3, 3), padding='same'))
Normalised_Model.add(BatchNormalization())
Normalised_Model.add(Activation('relu'))

Normalised_Model.add(MaxPooling2D(pool_size=(2, 2)))

Normalised_Model.add(Conv2D(32, (3, 3), padding='same'))
Normalised_Model.add(BatchNormalization())
Normalised_Model.add(Activation('relu'))

Normalised_Model.add(MaxPooling2D(pool_size=(2, 2)))

Normalised_Model.add(Conv2D(32, (3, 3), padding='same'))
Normalised_Model.add(BatchNormalization())
Normalised_Model.add(Activation('relu'))

Normalised_Model.add(MaxPooling2D(pool_size=(2, 2)))

Normalised_Model.add(Conv2D(64, (3, 3)))
Normalised_Model.add(BatchNormalization())
Normalised_Model.add(Activation('relu'))

Normalised_Model.add(MaxPooling2D(pool_size=(2, 2)))

Normalised_Model.add(Flatten())
Normalised_Model.add(Dense(512, activation='relu'))
Normalised_Model.add(Dense(256, activation='relu'))
Normalised_Model.add(Dropout(0.25))

Normalised_Model.add(Dense(9, activation='softmax'))


# having glance on layer summery
Normalised_Model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 32)      896
#
#  batch_normalization (BatchN  (None, 180, 180, 32)     128
#  ormalization)
#
#  activation (Activation)     (None, 180, 180, 32)      0
#
#  max_pooling2d_6 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 90, 90, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 90, 90, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 90, 90, 32)        0
#
#  max_pooling2d_7 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 45, 45, 32)        9248
#
#  batch_normalization_2 (Batc  (None, 45, 45, 32)       128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 45, 45, 32)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 20, 20, 64)        18496
#
#  batch_normalization_3 (Batc  (None, 20, 20, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 20, 20, 64)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 6400)              0
#
#  dense_4 (Dense)             (None, 512)               3277312
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 3,449,481
# Trainable params: 3,449,161
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# ### Compiling the 3rd model built after after adding 500 additinal images with adam optimiser

# %%
Normalised_Model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the 3rd model built after after adding 500 additinal images with 50 epoches

# %%
epochs = 30
history = Normalised_Model.fit(
  train_dataset,
  validation_data=validation_dataset ,
  epochs=epochs,
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 52s 263ms/step - loss: 2.0164 - accuracy: 0.3611 - val_loss: 2.6040 - val_accuracy: 0.1151
# Epoch 2/30
# 169/169 [==============================] - 41s 235ms/step - loss: 1.3392 - accuracy: 0.4991 - val_loss: 2.5181 - val_accuracy: 0.1411
# Epoch 3/30
# 169/169 [==============================] - 41s 233ms/step - loss: 1.1638 - accuracy: 0.5618 - val_loss: 1.3592 - val_accuracy: 0.4759
# Epoch 4/30
# 169/169 [==============================] - 42s 240ms/step - loss: 1.0111 - accuracy: 0.6233 - val_loss: 1.0831 - val_accuracy: 0.5835
# Epoch 5/30
# 169/169 [==============================] - 40s 230ms/step - loss: 0.8202 - accuracy: 0.6907 - val_loss: 1.4323 - val_accuracy: 0.5071
# Epoch 6/30
# 169/169 [==============================] - 43s 249ms/step - loss: 0.6995 - accuracy: 0.7337 - val_loss: 1.0975 - val_accuracy: 0.6147
# Epoch 7/30
# 169/169 [==============================] - 40s 232ms/step - loss: 0.6042 - accuracy: 0.7711 - val_loss: 2.0633 - val_accuracy: 0.5160
# Epoch 8/30
# 169/169 [==============================] - 40s 228ms/step - loss: 0.5163 - accuracy: 0.8058 - val_loss: 0.7640 - val_accuracy: 0.7372
# Epoch 9/30
# 169/169 [==============================] - 40s 228ms/step - loss: 0.4378 - accuracy: 0.8348 - val_loss: 0.7729 - val_accuracy: 0.7379
# Epoch 10/30
# 169/169 [==============================] - 40s 231ms/step - loss: 0.4158 - accuracy: 0.8446 - val_loss: 0.9563 - val_accuracy: 0.6756
# Epoch 11/30
# 169/169 [==============================] - 41s 235ms/step - loss: 0.3395 - accuracy: 0.8680 - val_loss: 0.7110 - val_accuracy: 0.7817
# Epoch 12/30
# 169/169 [==============================] - 41s 232ms/step - loss: 0.3032 - accuracy: 0.8828 - val_loss: 1.0084 - val_accuracy: 0.6748
# Epoch 13/30
# 169/169 [==============================] - 40s 232ms/step - loss: 0.3055 - accuracy: 0.8865 - val_loss: 0.9535 - val_accuracy: 0.6912
# Epoch 14/30
# 169/169 [==============================] - 40s 230ms/step - loss: 0.2466 - accuracy: 0.9011 - val_loss: 0.5896 - val_accuracy: 0.7921
# Epoch 15/30
# 169/169 [==============================] - 40s 229ms/step - loss: 0.2602 - accuracy: 0.8991 - val_loss: 1.2437 - val_accuracy: 0.6815
# Epoch 16/30
# 169/169 [==============================] - 40s 227ms/step - loss: 0.2405 - accuracy: 0.9075 - val_loss: 0.7508 - val_accuracy: 0.7728
# Epoch 17/30
# 169/169 [==============================] - 40s 230ms/step - loss: 0.2125 - accuracy: 0.9162 - val_loss: 0.7559 - val_accuracy: 0.7817
# Epoch 18/30
# 169/169 [==============================] - 41s 233ms/step - loss: 0.2026 - accuracy: 0.9184 - val_loss: 0.7608 - val_accuracy: 0.7699
# Epoch 19/30
# 169/169 [==============================] - 40s 232ms/step - loss: 0.1869 - accuracy: 0.9228 - val_loss: 0.7667 - val_accuracy: 0.7572
# Epoch 20/30
# 169/169 [==============================] - 40s 232ms/step - loss: 0.1799 - accuracy: 0.9264 - val_loss: 0.8072 - val_accuracy: 0.7854
# Epoch 21/30
# 169/169 [==============================] - 40s 231ms/step - loss: 0.1765 - accuracy: 0.9303 - val_loss: 0.8418 - val_accuracy: 0.7580
# Epoch 22/30
# 169/169 [==============================] - 40s 229ms/step - loss: 0.1802 - accuracy: 0.9269 - val_loss: 0.7898 - val_accuracy: 0.7765
# Epoch 23/30
# 169/169 [==============================] - 40s 227ms/step - loss: 0.1905 - accuracy: 0.9234 - val_loss: 1.4284 - val_accuracy: 0.6711
# Epoch 24/30
# 169/169 [==============================] - 40s 230ms/step - loss: 0.1893 - accuracy: 0.9269 - val_loss: 0.6373 - val_accuracy: 0.8241
# Epoch 25/30
# 169/169 [==============================] - 40s 230ms/step - loss: 0.1635 - accuracy: 0.9319 - val_loss: 0.9749 - val_accuracy: 0.7647
# Epoch 26/30
# 169/169 [==============================] - 40s 231ms/step - loss: 0.1645 - accuracy: 0.9377 - val_loss: 1.1895 - val_accuracy: 0.7097
# Epoch 27/30
# 169/169 [==============================] - 40s 232ms/step - loss: 0.1369 - accuracy: 0.9434 - val_loss: 0.6601 - val_accuracy: 0.8278
# Epoch 28/30
# 169/169 [==============================] - 40s 231ms/step - loss: 0.1665 - accuracy: 0.9329 - val_loss: 0.8101 - val_accuracy: 0.7929
# Epoch 29/30
# 169/169 [==============================] - 40s 232ms/step - loss: 0.1494 - accuracy: 0.9386 - val_loss: 0.9128 - val_accuracy: 0.7446
# Epoch 30/30
# 169/169 [==============================] - 40s 231ms/step - loss: 0.1511 - accuracy: 0.9416 - val_loss: 1.0589 - val_accuracy: 0.7669

# %% [markdown]
# **Visualizing the result**

# %%
accuracy = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, accuracy, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Findings:**
#
# Train Data Accuracy : 0.9329
#
# Train Loss : 0.1665
#
# Validation Data Accuracy : 0.7929
#
# Validation Loss - 0.8101
#
# **Nutshell:**
#
# we can see that this model's validation accuracy is higher than earlier models. This model, however, is also overfitting.
#
# Class rebalancing, droupout, and batch normalisation help achieve better results than a simple model.
#
#
# **Correction:**
#
# The Model can be further improved by tuning the hyperparameter.

# %% [markdown]
# ## Conclusion:
#
# We observe gradual improvement from Model 1 to Model 3:
#
# **Model 1:** Simple CNN Model
#
# Accuracy: 0.9244 | Validation accuracy : 0.5391
#
# **Model 2:** Augmented data with droupout
#
# Accuracy: 0.5965 | Validation accuracy : 0.5369
#
# **Model 3:** Class rebalance,BatchNormalization with Dropout
#
# Accuracy: 0.9329 | Validation accuracy : 0.7929
#
# With the right hyper-parameter tuning, accuracy can be improved even more. We can experiment with different CNN configurations, loss functions, optimizers, and layer counts to see accuracy pattern.
